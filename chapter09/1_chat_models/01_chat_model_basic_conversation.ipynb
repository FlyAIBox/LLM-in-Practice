# %% [markdown]
# <a href="https://colab.research.google.com/github/AlexFly666/LLM-in-Practice/blob/main/chapter09/1_chat_models/01_chat_model_basic_conversation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 安装依赖V0.2
# !pip install langchain-openai==0.1.8 \
#     langchain==0.2.1 \
#     langchain-community==0.2.1

# 安装依赖V0.3
# !pip install langchain-openai=0.3.4 \
#     langchain==0.3.17 \
#     langchain-community==0.3.16

# 使用最新版本安装依赖
# !pip install --upgrade --force-reinstall langchain-openai \
    langchain \
    langchain-community
# Out:
# ...
#   Using cached langchain_openai-0.3.4-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached langchain-0.3.17-py3-none-any.whl.metadata (7.1 kB)
# ...
#   Using cached langchain_community-0.3.16-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached langchain_core-0.3.34-py3-none-any.whl.metadata (5.9 kB)
# ...
#   Using cached tiktoken-0.8.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached langchain_text_splitters-0.3.6-py3-none-any.whl.metadata (1.9 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 4.5 MB/s eta 0:00:00
# ...
#   Using cached dataclasses_json-0.6.7-py3-none-any.whl.metadata (25 kB)
# ...
#   Using cached httpx_sse-0.4.0-py3-none-any.whl.metadata (9.0 kB)
# ...
#   Using cached pydantic_settings-2.7.1-py3-none-any.whl.metadata (3.5 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 69.2/69.2 kB 5.3 MB/s eta 0:00:00
# ...
#   Using cached marshmallow-3.26.1-py3-none-any.whl.metadata (7.3 kB)
# ...

# %%
# !pip show langchain-openai \
#     langchain \
#     langchain-community

# !pip show langchain-openai langchain langchain-community | grep -E "(Name|Version):" | awk -F: '{printf "%-25s %s\n", $1, $2}'
# Out:
# Name                       langchain-openai
# Version                    0.3.4
# Name                       langchain
# Version                    0.3.17
# Name                       langchain-community
# Version                    0.3.16

# %%
# 导入依赖
import langchain
from langchain_core.messages import AIMessage, HumanMessage, SystemMessage
from langchain_openai import ChatOpenAI

# %%
# 创建ChatOpenAI模型对象，连接DeepSeek Reasoner(deepseek-reasoner)模型
# model = ChatOpenAI(
#     api_key="XXX",
#     base_url="https://api.deepseek.com",
#     model="deepseek-chat"
# )
langchain.debug = True

# 智谱API调用(glm-4v-flash)
model = ChatOpenAI(
    api_key="XXX",
    base_url="https://open.bigmodel.cn/api/paas/v4/",
    model="glm-4v-flash"
)


# 第一次模型调用：询问数学问题
messages = [
    # 系统消息，告知模型执行数学问题的解答
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?")
]

# 调用模型并获取结果
result = model.invoke(messages)
print(f"Answer from AI: {result.content}")

# 第二次模型调用：连续问答
messages = [
    SystemMessage(content="Solve the following math problems"),
    HumanMessage(content="What is 81 divided by 9?"),
    AIMessage(content="81 divided by 9 is 9."),
    HumanMessage(content="What is 10 times 5?中文回答")
]

# 再次调用模型并获取第二个问题的答案
result = model.invoke(messages)
print(f"Answer from AI: {result.content}")
# Out:
# [llm/start] [llm:ChatOpenAI] Entering LLM run with input:
# {
#   "prompts": [
#     "System: Solve the following math problems\nHuman: What is 81 divided by 9?"
#   ]
# }
# [llm/end] [llm:ChatOpenAI] [3.00s] Exiting LLM run with output:
# {
#   "generations": [
#     [
#       {
#         "text": "81 divided by 9 equals 9.",
#         "generation_info": {
#           "finish_reason": "stop",
#           "logprobs": null
#         },
#         "type": "ChatGeneration",
#         "message": {
#           "lc": 1,
#           "type": "constructor",
#           "id": [
#             "langchain",
#             "schema",
#             "messages",
#             "AIMessage"
#           ],
#           "kwargs": {
#             "content": "81 divided by 9 equals 9.",
#             "response_metadata": {
#               "token_usage": {
#                 "completion_tokens": 10,
#                 "prompt_tokens": 24,
#                 "total_tokens": 34,
# ...
